# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\AnnieChao\AppData\Local\Temp\ipykernel_20028\2350612576.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape #rows, columns
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#clean up the data 
#only want USA Races, 50k or 50 miles, 2020

# %%
#step1 show 50 miles or 50k 
#50km 
#df[df["Event distance/length"]=='50km']

#50mi
#df[df["Event distance/length"]=='50mi']

#combine 50km and 50mi with isin 
df[df["Event distance/length"].isin(['50km','50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#df[(df["Event distance/length"].isin(['50km','50mi']))&(df["Year of event"]==2020)
  # &(df["Athlete country"]=='USA')]

# %%
df[(df["Event distance/length"].isin(['50km','50mi']))&(df["Year of event"]==2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
##df[df['Event name']=='Everglades 50 Mile Ultra Run (USA)']['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
#df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)=='USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#combine all the filters
df2=df[(df["Event distance/length"].isin(['50km','50mi']))&(df["Year of event"]==2020)&
   (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)=='USA')]

# %%
df2.head(10)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# 2539950           2020  02.02.2020
# 2539951           2020  02.02.2020
# 2539952           2020  02.02.2020
# 2539953           2020  02.02.2020
# 2539954           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539950  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2.shape
# Out:
# (26090, 13)

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26090, dtype: object

# %%
#overwrite this column
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\AnnieChao\AppData\Local\Temp\ipykernel_20028\1329445996.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %%
#Clean up athlete age 
#calculate the athlete age by subtracting by the year 
df2['Athlete_age'] = 2020-df2['Athlete year of birth']
# Out:
# C:\Users\AnnieChao\AppData\Local\Temp\ipykernel_20028\2029542090.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete_age'] = 2020-df2['Athlete year of birth']

# %%
#remove h from athlete performance 
df2['Athlete performance']=df2['Athlete performance'].str.split('h').str.get(0)
# Out:
# C:\Users\AnnieChao\AppData\Local\Temp\ipykernel_20028\3269318891.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance']=df2['Athlete performance'].str.split('h').str.get(0)

# %%
df2.head(2)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20            3:17:55
# 2539946                  50km                         20            4:02:32
#
#                Athlete club Athlete country  Athlete year of birth  \
# 2539945  *Normandy Park, WA             USA                 1991.0
# 2539946       *Gold Bar, WA             USA                 1981.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID  \
# 2539945              M                  M23                15.158       71287
# 2539946              M                  M35                12.369      629508
#
#          Athlete_age
# 2539945         29.0
# ...

# %%
#drop columns: Athlete country, athlete club, athlete year of birth, athlete age category 
df2= df2.drop(['Athlete club','Athlete country','Athlete year of birth','Athlete age category'],axis=1)

# %%
df2.head(2)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20            3:17:55
# 2539946                  50km                         20            4:02:32
#
#         Athlete gender Athlete average speed  Athlete ID  Athlete_age
# 2539945              M                15.158       71287         29.0
# 2539946              M                12.369      629508         39.0

# %%
#clean up null value 
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# Athlete_age                  233
# dtype: int64

# %%
df2[df2['Athlete_age'].isna()==1] #==1 True 0 False
# Out:
#          Year of event Event dates                           Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...                ...         ...                                  ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (25857, 10)

# %%
#check for duplicate values 
df2[df2.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, Athlete_age]
# Index: []

# %%
#reset index 
df2.reset_index(drop=True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 25852           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25853           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25854           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25855           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25856           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#fix types 
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# Athlete_age                  float64
# dtype: object

# %%
df2['Athlete_age']=df2['Athlete_age'].astype(int)

# %%
df2["Athlete average speed"]=df2["Athlete average speed"].astype(float)

# %%
df2.head(2)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20            3:17:55
# 2539946                  50km                         20            4:02:32
#
#         Athlete gender  Athlete average speed  Athlete ID  Athlete_age
# 2539945              M                 15.158       71287           29
# 2539946              M                 12.369      629508           39

# %%
#rename columns 
df3=df2.rename(columns={'Year of event': 'year',
    'Event dates':'race_day',
    'Event name':'race_name',
    'Event distance/length':'race_length',
    'Event number of finishers':'race_number_of_finishers',
    'Athlete performance':'athlete_performance',
    'Athlete gender':'athlete_gender',
    'Athlete average speed':'athlete_average_speed',
    'Athlete ID': 'athlete_id',
    'Athlete_age':'athlete_age'                   
                        
})

# %%
df3.head()
# Out:
#          year    race_day                                 race_name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         race_length  race_number_of_finishers athlete_performance  \
# 2539945        50km                        20            3:17:55
# 2539946        50km                        20            4:02:32
# 2539947        50km                        20            4:07:57
# 2539948        50km                        20            4:22:02
# 2539949        50km                        20            4:27:34
#
#         athlete_gender  athlete_average_speed  athlete_id  athlete_age
# 2539945              M                 15.158       71287           29
# ...

# %%
#Reorder the columns 
df3 = df3[['race_day','race_name','race_length','race_number_of_finishers','athlete_id',
           'athlete_gender','athlete_age','athlete_performance','athlete_average_speed']]

# %%
df3.head(2)
# Out:
#            race_day                                 race_name race_length  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2539945                        20       71287              M           29
# 2539946                        20      629508              M           39
#
#         athlete_performance  athlete_average_speed
# 2539945            3:17:55                  15.158
# 2539946            4:02:32                  12.369

# %%
#find the 2 races that I ran in 2020 - Sarasota/Everglades
df3[df3['race_name']=='Everglades 50 Mile Ultra Run ']
# Out:
#            race_day                      race_name race_length  \
# 2591476  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591477  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591478  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591479  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591480  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591481  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591483  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591484  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591485  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591486  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591487  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591488  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591489  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# ...

# %%
df3[df3['athlete_id']==222509]
# Out:
#            race_day                      race_name race_length  \
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2616900  22.02.2020       Manasota Track Club 50K         50km
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2591482                        40      222509              M           23
# 2616900                        36      222509              M           23
#
#         athlete_performance  athlete_average_speed
# 2591482            9:19:10                   8.634
# 2616900            4:49:16                  10.371

# %%
#Use Seaborn to create charts and graphs

# %%
sns.histplot(df3['race_length'])
# Out:
# <AxesSubplot:xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df3, x='race_length', hue='athlete_gender')
# Out:
# <AxesSubplot:xlabel='race_length', ylabel='Count'>

# %% [markdown]
# From the histogram we can observe that there are more males on the race than female

# %%
sns.displot(df3[df3['race_length']=='50mi']['athlete_average_speed'])

# %% [markdown]
# The average speed of the athlete is mostly around 6 or 7

# %%
sns.violinplot(data=df3, x='race_length', y='athlete_average_speed', hue='athlete_gender',
               split=True, inner='quart', linewidth=1)
# Out:
# <AxesSubplot:xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.lmplot(data=df3,x='athlete_age',y='athlete_average_speed', hue='athlete_gender')

# %%
#Questions to find out from the data

# %%
#Difference in speed for the 50km, 50mi male to female
#df3.groupby(['race_length', 'athlete_gender'])['athlete_average_speed'].mean()

df3.groupby(['race_length', 'athlete_gender'])['athlete_average_speed'].agg(['mean', 'median'])
# Out:
#                                 mean  median
# race_length athlete_gender
# 50km        F               7.083011   6.900
#             M               7.738985   7.503
# 50mi        F               6.834371   6.695
#             M               7.257633   7.011

# %% [markdown]
# For both genders, the mean and medium speeds are higher in the 50 km race compared to the 50mi race. Athletes tend to have a higher average speed in the 50km race compared to the 50mi race, which could be due to the shorter distance allowing for faster pacing. Male athletes show slightly higher average speeds than female athletes in both race lengths, though the difference is relatively small.

# %%
#what age group is the best in the 50mi race (20 + races minimum)
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean',ascending=False).query('count>19').head(15)
# Out:
#                  mean  count
# athlete_age
# 29           7.902252    135
# 23           7.779800     55
# 28           7.575252    107
# 30           7.569204    157
# 25           7.540923     91
# 31           7.451638    138
# 38           7.430022    231
# 35           7.422359    195
# 36           7.403854    185
# 26           7.379800     75
# 33           7.379188    149
# 22           7.367902     41
# 24           7.354274     73
# 42           7.327656    209
# 34           7.319011    182

# %%
#what age group is the worst in the 50mi race (20 + races minimum)
df3.query('race_length == "50mi"').groupby('athlete_age')[
    'athlete_average_speed'].agg(['mean','count']).sort_values('mean',ascending=True).query('count>19').head(15)
# Out:
#                  mean  count
# athlete_age
# 60           6.261788     33
# 62           6.272730     37
# 61           6.358355     31
# 63           6.514806     31
# 58           6.582328     67
# 64           6.620727     22
# 50           6.671541    172
# 59           6.672072     83
# 48           6.696853    136
# 56           6.708373     67
# 53           6.736969     96
# 57           6.783205     78
# 49           6.789553    159
# 54           6.805506     83
# 55           6.828623     69

# %%
#Season for the data -> slower in summer than in winter?

#spring 3-5
#summer 6-8
#fall 9-11
#winter 12-2 

#split between two decimals

# %%
df3['race_month']=df3['race_day'].str.split('.').str.get(1).astype(int)

# %%
df3['race_season'] = df3['race_month'].apply(lambda x: 'Winter' 
                                             if x > 11 else 'Fall' if x >8 else 'Summer' if x>5
                                             else 'Spring' if x>2 else 'Winter')

# %%
df3.head(2)
# Out:
#            race_day                                 race_name race_length  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2539945                        20       71287              M           29
# 2539946                        20      629508              M           39
#
#         athlete_performance  athlete_average_speed  race_month race_season
# 2539945            3:17:55                  15.158           2      Winter
# 2539946            4:02:32                  12.369           2      Winter

# %%
df3.groupby('race_season')['athlete_average_speed'].agg(['mean','count']).sort_values('mean',
                                                                                      ascending=False)
# Out:
#                  mean  count
# race_season
# Spring       7.684430   3294
# Winter       7.518187  11595
# Fall         7.406619   8315
# Summer       6.869336   2653

# %%
df3.query('race_length=="50mi"').groupby('race_season')['athlete_average_speed'].agg(['mean','count']).sort_values('mean',ascending=False)
# Out:
#                  mean  count
# race_season
# Fall         7.511585   1997
# Spring       7.082557    836
# Winter       7.048442   1977
# Summer       6.505776    817

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df3, x='race_season', y='athlete_average_speed', hue='athlete_gender')
# Out:
# <AxesSubplot:xlabel='race_season', ylabel='athlete_average_speed'>

# %% [markdown]
# The medium speed of male athletes remains consistently higher than the female athletes across all seasons.
# The speeds are generally higher in Winter, Fall, and Spring. This might due to the heat in the summer which slows the athlete down.

# %%
from scipy.stats import f_oneway

# %%
winter_speed = df3[df3['race_season']=='Winter']['athlete_average_speed']
fall_speed =df3[df3['race_season']=='Fall']['athlete_average_speed']
summer_speed= df3[df3['race_season']=='Summer']['athlete_average_speed']
spring_speed = df3[df3['race_season']=='Spring']['athlete_average_speed']
f_oneway(winter_speed, fall_speed, summer_speed, spring_speed)
# Out:
# F_onewayResult(statistic=132.2625359424394, pvalue=4.922514597217719e-85)

# %% [markdown]
# Since the p value is greatly smaller than 0.05, null hypothesis is rejected, this indicates that there is a significant difference in average speed across all the seasons.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey = pairwise_tukeyhsd(endog=df3['athlete_average_speed'], 
                          groups=df3['race_season'], 
                          alpha=0.05)
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#   Fall Spring   0.2778   0.0  0.1881  0.3675   True
#   Fall Summer  -0.5373   0.0 -0.6344 -0.4402   True
#   Fall Winter   0.1116   0.0   0.049  0.1742   True
# Spring Summer  -0.8151   0.0 -0.9287 -0.7015   True
# Spring Winter  -0.1662   0.0 -0.2523 -0.0802   True
# Summer Winter   0.6489   0.0  0.5551  0.7426   True
# ---------------------------------------------------

# %%
sns.boxplot(data=df3, x='race_season', y='athlete_average_speed')
# Out:
# <AxesSubplot:xlabel='race_season', ylabel='athlete_average_speed'>

# %% [markdown]
# Summer has the lowest median
# Summer Challenges: Training and hydration strategies could be critical for athletes during Summer races.
# Seasonal Preparation: Athletes may need to adjust their preparation and pacing strategies based on expected seasonal conditions.
